# %%
import os
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

# %% [markdown]
# # Import

# %%
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Dense, Flatten, Dropout, BatchNormalization, Reshape, LeakyReLU
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf

# %% [markdown]
# # MNIST 데이터 로드

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_valid, y_valid) = mnist.load_data()

# %%
x_train.shape, y_train.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
x_train = x_train.reshape(-1, 28, 28, 1)

# %%
x_train = x_train / 127.5 - 1

# %%
x_train.min(), x_train.max()
# Out:
# (-1.0, 1.0)

# %% [markdown]
# # Encoder 정의

# %%
encoder_input = tf.keras.Input(shape=(28, 28, 1))

# 28 X 28
x = Conv2D(32, 3, padding='same')(encoder_input) 
x = BatchNormalization()(x)
x = LeakyReLU()(x) 

# 28 X 28 -> 14 X 14
x = Conv2D(64, 3, strides=2, padding='same')(x)
x = BatchNormalization()(x) 
x = LeakyReLU()(x) 

# 14 X 14 -> 7 X 7
x = Conv2D(64, 3, strides=2, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# 17 X 7
x = Conv2D(64, 3, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

x = Flatten()(x)

# 2D 좌표로 표기하기 위하여 2를 출력값으로 지정합니다.
encoder_output = Dense(2)(x)

# %%
encoder = Model(encoder_input, encoder_output)

# %% [markdown]
# ### Encoder 모델 정의

# %%
encoder.summary()
# Out:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 6274
# =================================================================
# Total params: 99,842
# Trainable params: 99,394
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# # Decoder

# %%
# Input으로는 2D 좌표가 들어갑니다.
decoder_input = tf.keras.Input(shape=(2, ))

# 2D 좌표를 7*7*64 개의 neuron 출력 값을 가지도록 변경합니다.
x = Dense(7*7*64)(decoder_input)
x = Reshape( (7, 7, 64))(x)

# 7 X 7 -> 7 X 7
x = Conv2DTranspose(64, 3, strides=1, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# 7 X 7 -> 14 X 14
x = Conv2DTranspose(64, 3, strides=2, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# 14 X 14 -> 28 X 28
x = Conv2DTranspose(64, 3, strides=2, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# 28 X 28 -> 28 X 28
x = Conv2DTranspose(32, 3, strides=1, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# 최종 output
decoder_output = Conv2DTranspose(1, 3, strides=1, padding='same', activation='tanh')(x)

# %% [markdown]
# ### Decoder 모델 정의

# %%
decoder = Model(decoder_input, decoder_output)

# %%
decoder.summary()
# Out:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3136)              9408
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_transpose_6 (Conv2DTr (None, 14, 14, 64)        36928
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 14, 14, 64)        256
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 28, 28, 64)        36928
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 28, 28, 64)        256
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_transpose_8 (Conv2DTr (None, 28, 28, 32)        18464
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 28, 28, 32)        128
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_transpose_9 (Conv2DTr (None, 28, 28, 1)         289
# =================================================================
# Total params: 139,841
# Trainable params: 139,393
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# # Hyperparameter 정의

# %%
LEARNING_RATE = 0.0005
BATCH_SIZE = 32

# %% [markdown]
# # Encoder + Decoder

# %%
encoder_in = tf.keras.Input(shape=(28, 28, 1))
x = encoder(encoder_in)
decoder_out = decoder(x)

# %% [markdown]
# # Auto Encoder 모델 최종 정의

# %%
auto_encoder = Model(encoder_in, decoder_out)

# %% [markdown]
# # Auto Encoder 모델 compile

# %%
auto_encoder.compile(optimizer=tf.keras.optimizers.Adam(LEARNING_RATE), loss=tf.keras.losses.mean_squared_error)

# %% [markdown]
# - 체크포인트 정의

# %%
checkpoint_path = 'tmp/01-basic-auto-encoder-MNIST.ckpt'
checkpoint = ModelCheckpoint(checkpoint_path,
                            save_best_only=True,
                            save_weights_only=True,
                            monitor='loss',
                            verbose=1)

# %% [markdown]
# - 학습 시작

# %%
auto_encoder.fit(x_train, x_train,
                batch_size=BATCH_SIZE,
                epochs=100,
                callbacks=[checkpoint],
                )
# Out:
# Epoch 1/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.2045
# Epoch 00001: loss improved from inf to 0.20448, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2045
# Epoch 2/100
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1841
# Epoch 00002: loss improved from 0.20448 to 0.18411, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1841
# Epoch 3/100
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.1783
# Epoch 00003: loss improved from 0.18411 to 0.17821, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1782
# Epoch 4/100
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1736
# Epoch 00004: loss improved from 0.17821 to 0.17357, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1736
# Epoch 5/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1703
# Epoch 00005: loss improved from 0.17357 to 0.17034, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1703
# Epoch 6/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1679
# Epoch 00006: loss improved from 0.17034 to 0.16789, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1679
# Epoch 7/100
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.1658
# Epoch 00007: loss improved from 0.16789 to 0.16586, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1659
# Epoch 8/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1643
# Epoch 00008: loss improved from 0.16586 to 0.16427, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1643
# Epoch 9/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1631
# Epoch 00009: loss improved from 0.16427 to 0.16305, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1631
# Epoch 10/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1619
# Epoch 00010: loss improved from 0.16305 to 0.16190, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1619
# Epoch 11/100
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.1611
# Epoch 00011: loss improved from 0.16190 to 0.16108, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1611
# Epoch 12/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1603
# Epoch 00012: loss improved from 0.16108 to 0.16033, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1603
# Epoch 13/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1595
# Epoch 00013: loss improved from 0.16033 to 0.15951, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1595
# Epoch 14/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1589
# Epoch 00014: loss improved from 0.15951 to 0.15887, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1589
# Epoch 15/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1582
# Epoch 00015: loss improved from 0.15887 to 0.15817, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1582
# Epoch 16/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1576
# Epoch 00016: loss improved from 0.15817 to 0.15755, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1575
# Epoch 17/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1571
# Epoch 00017: loss improved from 0.15755 to 0.15709, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1571
# Epoch 18/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1566
# Epoch 00018: loss improved from 0.15709 to 0.15660, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1566
# Epoch 19/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1563
# Epoch 00019: loss improved from 0.15660 to 0.15629, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1563
# Epoch 20/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1556
# Epoch 00020: loss improved from 0.15629 to 0.15565, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1556
# Epoch 21/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1553
# Epoch 00021: loss improved from 0.15565 to 0.15532, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1553
# Epoch 22/100
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1551
# Epoch 00022: loss improved from 0.15532 to 0.15506, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1551
# Epoch 23/100
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.1546
# Epoch 00023: loss improved from 0.15506 to 0.15465, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1546
# Epoch 24/100
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1543
# Epoch 00024: loss improved from 0.15465 to 0.15435, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1543
# Epoch 25/100
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1539
# Epoch 00025: loss improved from 0.15435 to 0.15389, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1539
# Epoch 26/100
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.1537
# Epoch 00026: loss improved from 0.15389 to 0.15374, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1537
# Epoch 27/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1533
# Epoch 00027: loss improved from 0.15374 to 0.15330, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1533
# Epoch 28/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1531
# Epoch 00028: loss improved from 0.15330 to 0.15310, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1531
# Epoch 29/100
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1529
# Epoch 00029: loss improved from 0.15310 to 0.15293, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1529
# Epoch 30/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1527
# Epoch 00030: loss improved from 0.15293 to 0.15265, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1527
# Epoch 31/100
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.1524
# Epoch 00031: loss improved from 0.15265 to 0.15245, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1525
# Epoch 32/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1521
# Epoch 00032: loss improved from 0.15245 to 0.15210, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1521
# Epoch 33/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1519
# Epoch 00033: loss improved from 0.15210 to 0.15190, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1519
# Epoch 34/100
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.1518
# Epoch 00034: loss improved from 0.15190 to 0.15178, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1518
# Epoch 35/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1514
# Epoch 00035: loss improved from 0.15178 to 0.15139, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1514
# Epoch 36/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1511
# Epoch 00036: loss improved from 0.15139 to 0.15113, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1511
# Epoch 37/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1510
# Epoch 00037: loss improved from 0.15113 to 0.15102, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1510
# Epoch 38/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1508
# Epoch 00038: loss improved from 0.15102 to 0.15079, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1508
# Epoch 39/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1506
# Epoch 00039: loss improved from 0.15079 to 0.15064, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1506
# Epoch 40/100
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.1505
# Epoch 00040: loss improved from 0.15064 to 0.15052, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1505
# Epoch 41/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1501
# Epoch 00041: loss improved from 0.15052 to 0.15013, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1501
# Epoch 42/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1500
# Epoch 00042: loss improved from 0.15013 to 0.15001, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1500
# Epoch 43/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1498
# Epoch 00043: loss improved from 0.15001 to 0.14981, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1498
# Epoch 44/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1498
# Epoch 00044: loss improved from 0.14981 to 0.14978, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1498
# Epoch 45/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1494
# Epoch 00045: loss improved from 0.14978 to 0.14943, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1494
# Epoch 46/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1494
# Epoch 00046: loss did not improve from 0.14943
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1494
# Epoch 47/100
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.1492
# Epoch 00047: loss improved from 0.14943 to 0.14918, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1492
# Epoch 48/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1491
# Epoch 00048: loss improved from 0.14918 to 0.14905, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1490
# Epoch 49/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1489
# Epoch 00049: loss improved from 0.14905 to 0.14893, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1489
# Epoch 50/100
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.1488
# Epoch 00050: loss improved from 0.14893 to 0.14883, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1488
# Epoch 51/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1486
# Epoch 00051: loss improved from 0.14883 to 0.14863, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1486
# Epoch 52/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1485
# Epoch 00052: loss improved from 0.14863 to 0.14853, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1485
# Epoch 53/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1483
# Epoch 00053: loss improved from 0.14853 to 0.14832, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1483
# Epoch 54/100
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1482
# Epoch 00054: loss improved from 0.14832 to 0.14818, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1482
# Epoch 55/100
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.1481
# Epoch 00055: loss improved from 0.14818 to 0.14806, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1481
# Epoch 56/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1479
# Epoch 00056: loss improved from 0.14806 to 0.14791, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1479
# Epoch 57/100
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.1479
# Epoch 00057: loss improved from 0.14791 to 0.14789, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1479
# Epoch 58/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1477
# Epoch 00058: loss improved from 0.14789 to 0.14765, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1477
# Epoch 59/100
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.1476
# Epoch 00059: loss improved from 0.14765 to 0.14757, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1476
# Epoch 60/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1474
# Epoch 00060: loss improved from 0.14757 to 0.14745, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1474
# Epoch 61/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1473
# Epoch 00061: loss improved from 0.14745 to 0.14731, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1473
# Epoch 62/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1471
# Epoch 00062: loss improved from 0.14731 to 0.14715, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1471
# Epoch 63/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1470
# Epoch 00063: loss improved from 0.14715 to 0.14700, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1470
# Epoch 64/100
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.1469
# Epoch 00064: loss improved from 0.14700 to 0.14692, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1469
# Epoch 65/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1469
# Epoch 00065: loss improved from 0.14692 to 0.14686, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1469
# Epoch 66/100
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.1467
# Epoch 00066: loss improved from 0.14686 to 0.14669, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1467
# Epoch 67/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1467
# Epoch 00067: loss improved from 0.14669 to 0.14667, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1467
# Epoch 68/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1465
# Epoch 00068: loss improved from 0.14667 to 0.14648, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1465
# Epoch 69/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1464
# Epoch 00069: loss improved from 0.14648 to 0.14635, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1464
# Epoch 70/100
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.1463
# Epoch 00070: loss improved from 0.14635 to 0.14632, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1463
# Epoch 71/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1461
# Epoch 00071: loss improved from 0.14632 to 0.14615, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1461
# Epoch 72/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1461
# Epoch 00072: loss improved from 0.14615 to 0.14614, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1461
# Epoch 73/100
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.1459
# Epoch 00073: loss improved from 0.14614 to 0.14592, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1459
# Epoch 74/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1460
# Epoch 00074: loss did not improve from 0.14592
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1460
# Epoch 75/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1458
# Epoch 00075: loss improved from 0.14592 to 0.14574, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1457
# Epoch 76/100
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.1458
# Epoch 00076: loss did not improve from 0.14574
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1458
# Epoch 77/100
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1457
# Epoch 00077: loss improved from 0.14574 to 0.14566, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1457
# Epoch 78/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1455
# Epoch 00078: loss improved from 0.14566 to 0.14554, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1455
# Epoch 79/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1455
# Epoch 00079: loss improved from 0.14554 to 0.14546, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1455
# Epoch 80/100
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1454
# Epoch 00080: loss improved from 0.14546 to 0.14537, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1454
# Epoch 81/100
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.1452
# Epoch 00081: loss improved from 0.14537 to 0.14522, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1452
# Epoch 82/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1451
# Epoch 00082: loss improved from 0.14522 to 0.14513, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1451
# Epoch 83/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1451
# Epoch 00083: loss improved from 0.14513 to 0.14509, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1451
# Epoch 84/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1450
# Epoch 00084: loss improved from 0.14509 to 0.14495, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1449
# Epoch 85/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1450
# Epoch 00085: loss did not improve from 0.14495
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1450
# Epoch 86/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1448
# Epoch 00086: loss improved from 0.14495 to 0.14474, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1447
# Epoch 87/100
# 1871/1875 [============================>.] - ETA: 0s - loss: 0.1447
# Epoch 00087: loss did not improve from 0.14474
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1448
# Epoch 88/100
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1446
# Epoch 00088: loss improved from 0.14474 to 0.14466, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1447
# Epoch 89/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1447
# Epoch 00089: loss did not improve from 0.14466
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1447
# Epoch 90/100
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1445
# Epoch 00090: loss improved from 0.14466 to 0.14448, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1445
# Epoch 91/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1444
# Epoch 00091: loss improved from 0.14448 to 0.14442, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1444
# Epoch 92/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1442
# Epoch 00092: loss improved from 0.14442 to 0.14420, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1442
# Epoch 93/100
# 1875/1875 [==============================] - ETA: 0s - loss: 0.1442
# Epoch 00093: loss did not improve from 0.14420
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1442
# Epoch 94/100
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1441
# Epoch 00094: loss improved from 0.14420 to 0.14407, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1441
# Epoch 95/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1440
# Epoch 00095: loss improved from 0.14407 to 0.14405, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1440
# Epoch 96/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1439
# Epoch 00096: loss improved from 0.14405 to 0.14393, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1439
# Epoch 97/100
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.1440
# Epoch 00097: loss did not improve from 0.14393
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1440
# Epoch 98/100
# 1874/1875 [============================>.] - ETA: 0s - loss: 0.1438
# Epoch 00098: loss improved from 0.14393 to 0.14384, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1438
# Epoch 99/100
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.1438
# Epoch 00099: loss improved from 0.14384 to 0.14378, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1438
# Epoch 100/100
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1438
# Epoch 00100: loss improved from 0.14378 to 0.14375, saving model to tmp/01-basic-auto-encoder-MNIST.ckpt
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1437

# %%
auto_encoder.load_weights(checkpoint_path)

# %% [markdown]
# # 시각화

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# MNIST 이미지에 대하여 x, y 좌표로 뽑아낸다.
xy = encoder.predict(x_train)

# %%
xy.shape, y_train.shape
# Out:
# ((60000, 2), (60000,))

# %% [markdown]
# # 인코더의 X, Y좌표 값을 시각화

# %%
plt.figure(figsize=(15, 12))
plt.scatter(x=xy[:, 0], y=xy[:, 1], c=y_train, cmap=plt.get_cmap('Paired'), s=3)
plt.colorbar()
plt.show()

# %% [markdown]
# # Auto Encoder를 통한 이미지 재생성 성능 비교 시각화

# %%
decoded_images = auto_encoder.predict(x_train)

# %%
fig, axes = plt.subplots(3, 5)
fig.set_size_inches(12, 6)
for i in range(15):
    axes[i//5, i%5].imshow(x_train[i].reshape(28, 28), cmap='gray')
    axes[i//5, i%5].axis('off')
plt.tight_layout()
plt.title('Original Images')
plt.show()

fig, axes = plt.subplots(3, 5)
fig.set_size_inches(12, 6)
for i in range(15):
    axes[i//5, i%5].imshow(decoded_images[i].reshape(28, 28), cmap='gray')
    axes[i//5, i%5].axis('off')
plt.tight_layout()
plt.title('Auto Encoder Images')
plt.show()
